# %%
nums = [1,2,3]
mixed = [1,"a", True,3.14]
nested = [[1,2],[3,4]]
empty = list() #[]

# %%
print(nums)
# Out:
# [1, 2, 3]

# %%
print(mixed)
# Out:
# [1, 'a', True, 3.14]

# %%
print(nested)
# Out:
# [[1, 2], [3, 4]]

# %%
print(empty)
# Out:
# []

# %%
a = [10, 20, 30, 40, 50] # Initialize 'a' as a list
a.append(60)
a.extend([70, 80])
a.insert(1, 15)
a.remove(30)
val = a.pop()
idx = a.index(40)
count = a.count(20)
a.sort()
b = sorted(a, reverse=True)
# a.sorted() is not a valid method for lists; 'sorted()' is a built-in function
# If the intent was to sort 'a' in place, 'a.sort()' is already used. If it was to get a new sorted list, then 'b = sorted(a)' is appropriate.
# I will remove the invalid line 'a.sorted()'.

# %%
print(a)
# Out:
# [10, 15, 20, 40, 50, 60, 70]

# %%
print(a.append(60))
print(a)
# Out:
# None
# [10, 15, 20, 40, 50, 60, 70, 60]

# %%
a.extend([70,80])
print(a)
# Out:
# [10, 15, 20, 40, 50, 60, 70, 60, 60, 70, 80, 70, 80]

# %%
a.insert(1, 15)
print(a)
# Out:
# [10, 15, 15, 15, 20, 40, 50, 60, 70, 60, 60, 70, 80, 70, 80]

# %%
a.remove(10)
print(a)
# Out:
# [15, 15, 15, 20, 40, 50, 60, 70, 60, 60, 70, 80, 70, 80]

# %%
val = a.pop()
print(a)
# Out:
# [10, 15, 20, 40, 50]

# %%
squares = [x*x for x in range(6)]
evens = [x for x in range(10) if x % 2 ==0 ]
pairs =  [(i, j)for i in range(2)for j in range(2)]

# %%
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
print(evens)
# Out:
# [0, 2, 4, 6, 8]

# %%
print(pairs)
# Out:
# [(0, 0), (0, 1), (1, 0), (1, 1)]

# %%
marks = [78,85,392,67,88]
marks.remove(min(marks))
print(marks)
# Out:
# [78, 85, 392, 88]

# %%
marks.append(90)
print(marks)
# Out:
# [78, 85, 392, 88, 90]

# %%
marks.sort(reverse=True)
print(marks)
# Out:
# [392, 90, 88, 85, 78]

# %%
top_3 = marks[:3]
print(top_3)
# Out:
# [392, 90, 88]

# %%
average_top3 = sum(top_3)/ len(top_3)
print(average_top3)
# Out:
# 190.0

# %%
print("Updates Marks:",marks)
# Out:
# Updates Marks: [392, 90, 88, 85, 78]

# %%
print("Top 3 Marks:",top_3)
# Out:
# Top 3 Marks: [392, 90, 88]

# %%
print("Average of Top 3 Marks:",average_top3)
# Out:
# Average of Top 3 Marks: 190.0

# %%
t = (1,2,3)
single = (42, )
packed = 1,2,3
print(t)
# Out:
# (1, 2, 3)

# %%
print(single)
# Out:
# (42,)

# %%
print(packed)
# Out:
# (1, 2, 3)

# %%
emp = {"id": 101,"name":"Asha","dept":"HR"}
alt = dict(id=101, name="Asha",dept="HR")
empty={}

# %%
emp['name']
# Out:
# 'Asha'

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1324/87984422.py in <cell line: 0>()
# ----> 1 emp['email']
#
# KeyError: 'email'

# %%
for k in emp:
  print(k)
  for k, v in emp.items():
    print(k,v)
    for v in emp.values():
      print(v)
# Out:
# id
# id 101
# 101
# Asha
# HR
# name Asha
# 101
# Asha
# HR
# dept HR
# 101
# Asha
# HR
# name
# id 101
# 101
# Asha
# HR
# name Asha
# 101
# Asha
# HR
# dept HR
# 101
# Asha
# HR
# dept
# id 101
# 101
# Asha
# HR
# name Asha
# 101
# Asha
# HR
# dept HR
# 101
# Asha
# HR

# %%
for k in emp:
  print(k)
  for k, v in emp.items():
    print(k,v)
    for v in emp.values():
      print(v)
# Out:
# id
# id 101
# 101
# Asha
# HR
# name Asha
# 101
# Asha
# HR
# dept HR
# 101
# Asha
# HR
# name
# id 101
# 101
# Asha
# HR
# name Asha
# 101
# Asha
# HR
# dept HR
# 101
# Asha
# HR
# dept
# id 101
# 101
# Asha
# HR
# name Asha
# 101
# Asha
# HR
# dept HR
# 101
# Asha
# HR

# %%
text ="mississippi"
count = {}
for char in text :
  count[char]=count.get(char,0)+1
  print(count)
# Out:
# {'m': 1}
# {'m': 1, 'i': 1}
# {'m': 1, 'i': 1, 's': 1}
# {'m': 1, 'i': 1, 's': 2}
# {'m': 1, 'i': 2, 's': 2}
# {'m': 1, 'i': 2, 's': 3}
# {'m': 1, 'i': 2, 's': 4}
# {'m': 1, 'i': 3, 's': 4}
# {'m': 1, 'i': 3, 's': 4, 'p': 1}
# {'m': 1, 'i': 3, 's': 4, 'p': 2}
# {'m': 1, 'i': 4, 's': 4, 'p': 2}

# %%
for k in emp:
  print(k)
for k, v in emp.items():
    print(k,v)
for v in emp.values():
      print(v)
# Out:
# id
# name
# dept
# id 101
# name Asha
# dept HR
# 101
# Asha
# HR

# %%
person = {"name":"Asha","addr":{"city":"Pune","pin":411001}}
city = person["addr"]["city"]

print(city)
# Out:
# Pune

# %%
fruits = {"apple","banana","cherry","date","banana"}
print(fruits)
#
# Out:
# {'apple', 'banana', 'cherry', 'date'}

# %%
set1 = {1,2,3,4}
set2 = {3,4,5,6}
set1.add(10)
set1.discard(2)
print("Union:", set1|set2)
print("Intersection:", set1&set2)
print("Difference:", set1-set2)
print("Is Subset?",{3,4}.issubset(set1))
# Out:
# Union: {1, 3, 4, 5, 6, 10}
# Intersection: {3, 4}
# Difference: {1, 10}
# Is Subset? True
